# %%
import boto3
import pandas as pd
from fhir.resources.patient import Patient
from snowflake.connector import connect

# AWS S3 Configuration
s3 = boto3.client('s3')
bucket_name = 'your-s3-bucket'
raw_data_key = 'raw/healthcare_data.csv'

# Snowflake Configuration
snowflake_connection = connect(
    user='your_user',
    password='your_password',
    account='your_account',
    warehouse='your_warehouse',
    database='your_database',
    schema='your_schema'
)

# Step 1: Extract Data from S3
def extract_data_from_s3():
    obj = s3.get_object(Bucket=bucket_name, Key=raw_data_key)
    raw_data = pd.read_csv(obj['Body'])
    print(f"Data extracted from S3 with {len(raw_data)} records.")
    return raw_data

# Step 2: Transform Data (FHIR Standardization)
def transform_data_to_fhir(raw_data):
    fhir_data = []
    for _, row in raw_data.iterrows():
        patient = Patient.construct(
            id=row['patient_id'],
            name=[{"family": row['last_name'], "given": [row['first_name']]}],
            gender=row['gender'],
            birthDate=row['dob']
        )
        fhir_data.append(patient.dict())
    fhir_df = pd.DataFrame(fhir_data)
    print("Data transformed to FHIR standard.")
    return fhir_df

# Step 3: Load Data into Snowflake
def load_data_to_snowflake(fhir_df):
    cursor = snowflake_connection.cursor()
    cursor.execute("CREATE OR REPLACE TABLE healthcare_data (id STRING, name STRING, gender STRING, birthDate STRING)")
    for _, row in fhir_df.iterrows():
        insert_query = f"""
        INSERT INTO healthcare_data (id, name, gender, birthDate)
        VALUES ('{row['id']}', '{row['name']}', '{row['gender']}', '{row['birthDate']}')
        """
        cursor.execute(insert_query)
    cursor.close()
    print("Data loaded into Snowflake.")

# Main Pipeline Execution
if __name__ == "__main__":
    # Step 1: Extract
    raw_data = extract_data_from_s3()
    
    # Step 2: Transform
    fhir_transformed_data = transform_data_to_fhir(raw_data)
    
    # Step 3: Load
    load_data_to_snowflake(fhir_transformed_data)
    
    print("ETL Pipeline completed successfully.")
# Out:
# ---------------------------------------------------------------------------
# InterfaceError                            Traceback (most recent call last)
# Cell In[1], line 12
#       9 raw_data_key = 'raw/healthcare_data.csv'
#      11 # Snowflake Configuration
# ---> 12 snowflake_connection = connect(
#      13     user='your_user',
#      14     password='your_password',
#      15     account='your_account',
#      16     warehouse='your_warehouse',
#      17     database='your_database',
#      18     schema='your_schema'
#      19 )
#      21 # Step 1: Extract Data from S3
#      22 def extract_data_from_s3():
#
# File ~/anaconda3/lib/python3.11/site-packages/snowflake/connector/__init__.py:55, in Connect(**kwargs)
#      53 @wraps(SnowflakeConnection.__init__)
#      54 def Connect(**kwargs) -> SnowflakeConnection:
# ---> 55     return SnowflakeConnection(**kwargs)
#
# File ~/anaconda3/lib/python3.11/site-packages/snowflake/connector/connection.py:457, in SnowflakeConnection.__init__(self, connection_name, connections_file_path, **kwargs)
#     455     kwargs = _get_default_connection_params()
#     456 self.__set_error_attributes()
# --> 457 self.connect(**kwargs)
#     458 self._telemetry = TelemetryClient(self._rest)
#     459 self.expired = False
#
# File ~/anaconda3/lib/python3.11/site-packages/snowflake/connector/connection.py:772, in SnowflakeConnection.connect(self, **kwargs)
#     770             raise Exception(str(exceptions_dict))
#     771 else:
# --> 772     self.__open_connection()
#
# File ~/anaconda3/lib/python3.11/site-packages/snowflake/connector/connection.py:1100, in SnowflakeConnection.__open_connection(self)
#    1092 else:
#    1093     # okta URL, e.g., https://<account>.okta.com/
#    1094     self.auth_class = AuthByOkta(
#    1095         application=self.application,
#    1096         timeout=self.login_timeout,
#    1097         backoff_generator=self._backoff_generator,
#    1098     )
# -> 1100 self.authenticate_with_retry(self.auth_class)
#    1102 self._password = None  # ensure password won't persist
#    1103 self.auth_class.reset_secrets()
#
# File ~/anaconda3/lib/python3.11/site-packages/snowflake/connector/connection.py:1387, in SnowflakeConnection.authenticate_with_retry(self, auth_instance)
#    1384 def authenticate_with_retry(self, auth_instance) -> None:
#    1385     # make some changes if needed before real __authenticate
#    1386     try:
# -> 1387         self._authenticate(auth_instance)
#    1388     except ReauthenticationRequest as ex:
#    1389         # cached id_token expiration error, we have cleaned id_token and try to authenticate again
#    1390         logger.debug("ID token expired. Reauthenticating...: %s", ex)
#
# File ~/anaconda3/lib/python3.11/site-packages/snowflake/connector/connection.py:1415, in SnowflakeConnection._authenticate(self, auth_instance)
#    1413 auth_instance._retry_ctx.set_start_time()
#    1414 try:
# -> 1415     auth.authenticate(
#    1416         auth_instance=auth_instance,
#    1417         account=self.account,
#    1418         user=self.user,
#    1419         database=self.database,
#    1420         schema=self.schema,
#    1421         warehouse=self.warehouse,
#    1422         role=self.role,
#    1423         passcode=self._passcode,
#    1424         passcode_in_password=self._passcode_in_password,
#    1425         mfa_callback=self._mfa_callback,
#    1426         password_callback=self._password_callback,
#    1427         session_parameters=self._session_parameters,
#    1428     )
#    1429 except OperationalError as e:
#    1430     logger.debug(
#    1431         "Operational Error raised at authentication"
#    1432         f"for authenticator: {type(auth_instance).__name__}"
#    1433     )
#
# File ~/anaconda3/lib/python3.11/site-packages/snowflake/connector/auth/_auth.py:264, in Auth.authenticate(self, auth_instance, account, user, database, schema, warehouse, role, passcode, passcode_in_password, mfa_callback, password_callback, session_parameters, timeout)
#     255 logger.debug(
#     256     "body['data']: %s",
#     257     {
#    (...)
#     260     },
#     261 )
#     263 try:
# --> 264     ret = self._rest._post_request(
#     265         url,
#     266         headers,
#     267         json.dumps(body),
#     268         socket_timeout=auth_instance._socket_timeout,
#     269     )
#     270 except ForbiddenError as err:
#     271     # HTTP 403
#     272     raise err.__class__(
#     273         msg=(
#     274             "Failed to connect to DB. "
#    (...)
#     281         sqlstate=SQLSTATE_CONNECTION_WAS_NOT_ESTABLISHED,
#     282     )
#
# File ~/anaconda3/lib/python3.11/site-packages/snowflake/connector/network.py:748, in SnowflakeRestful._post_request(self, url, headers, body, token, timeout, socket_timeout, _no_results, no_retry, _include_retry_params)
#     745     ret = probe_connection(full_url)
#     746     pprint(ret)
# --> 748 ret = self.fetch(
#     749     "post",
#     750     full_url,
#     751     headers,
#     752     data=body,
#     753     timeout=timeout,
#     754     token=token,
#     755     no_retry=no_retry,
#     756     _include_retry_params=_include_retry_params,
#     757     socket_timeout=socket_timeout,
#     758 )
#     759 logger.debug(
#     760     "ret[code] = {code}, after post request".format(
#     761         code=(ret.get("code", "N/A"))
#     762     )
#     763 )
#     765 if ret.get("code") == MASTER_TOKEN_EXPIRED_GS_CODE:
#
# File ~/anaconda3/lib/python3.11/site-packages/snowflake/connector/network.py:863, in SnowflakeRestful.fetch(self, method, full_url, headers, data, timeout, **kwargs)
#     861 retry_ctx.set_start_time()
#     862 while True:
# --> 863     ret = self._request_exec_wrapper(
#     864         session, method, full_url, headers, data, retry_ctx, **kwargs
#     865     )
#     866     if ret is not None:
#     867         return ret
#
# File ~/anaconda3/lib/python3.11/site-packages/snowflake/connector/network.py:991, in SnowflakeRestful._request_exec_wrapper(self, session, method, full_url, headers, data, retry_ctx, no_retry, token, **kwargs)
#     987 except Exception as e:
#     988     if (
#     989         raise_raw_http_failure and isinstance(e, requests.exceptions.HTTPError)
#     990     ) or not no_retry:
# --> 991         raise e
#     992     logger.debug("Ignored error", exc_info=True)
#     993     return {}
#
# File ~/anaconda3/lib/python3.11/site-packages/snowflake/connector/network.py:913, in SnowflakeRestful._request_exec_wrapper(self, session, method, full_url, headers, data, retry_ctx, no_retry, token, **kwargs)
#     911 raise_raw_http_failure = kwargs.pop("raise_raw_http_failure", False)
#     912 try:
# --> 913     return_object = self._request_exec(
#     914         session=session,
#     915         method=method,
#     916         full_url=full_url,
#     917         headers=headers,
#     918         data=data,
#     919         token=token,
#     920         raise_raw_http_failure=raise_raw_http_failure,
#     921         **kwargs,
#     922     )
#     923     if return_object is not None:
#     924         return return_object
#
# File ~/anaconda3/lib/python3.11/site-packages/snowflake/connector/network.py:1190, in SnowflakeRestful._request_exec(self, session, method, full_url, headers, data, token, catch_okta_unauthorized_error, is_raw_text, is_raw_binary, binary_data_handler, socket_timeout, is_okta_authentication, raise_raw_http_failure)
#    1188         raise RetryRequest(err)
#    1189 except Exception as err:
# -> 1190     raise err
#
# File ~/anaconda3/lib/python3.11/site-packages/snowflake/connector/network.py:1139, in SnowflakeRestful._request_exec(self, session, method, full_url, headers, data, token, catch_okta_unauthorized_error, is_raw_text, is_raw_binary, binary_data_handler, socket_timeout, is_okta_authentication, raise_raw_http_failure)
#    1137         if raise_raw_http_failure:
#    1138             raw_ret.raise_for_status()
# -> 1139         raise_failed_request_error(
#    1140             self._connection, full_url, method, raw_ret
#    1141         )
#    1142         return None  # required for tests
#    1143 finally:
#
# File ~/anaconda3/lib/python3.11/site-packages/snowflake/connector/network.py:231, in raise_failed_request_error(connection, url, method, response)
#     225 def raise_failed_request_error(
#     226     connection: SnowflakeConnection | None,
#     227     url: str,
#     228     method: str,
#     229     response: Response,
#     230 ) -> None:
# --> 231     Error.errorhandler_wrapper(
#     232         connection,
#     233         None,
#     234         InterfaceError,
#     235         {
#     236             "msg": f"{response.status_code} {response.reason}: {method} {url}",
#     237             "errno": ER_FAILED_TO_REQUEST,
#     238             "sqlstate": SQLSTATE_CONNECTION_WAS_NOT_ESTABLISHED,
#     239         },
#     240     )
#
# File ~/anaconda3/lib/python3.11/site-packages/snowflake/connector/errors.py:284, in Error.errorhandler_wrapper(connection, cursor, error_class, error_value)
#     261 @staticmethod
#     262 def errorhandler_wrapper(
#     263     connection: SnowflakeConnection | None,
#    (...)
#     266     error_value: dict[str, Any],
#     267 ) -> None:
#     268     """Error handler wrapper that calls the errorhandler method.
#     269
#     270     Args:
#    (...)
#     281         exception to the first handler in that order.
#     282     """
# --> 284     handed_over = Error.hand_to_other_handler(
#     285         connection,
#     286         cursor,
#     287         error_class,
#     288         error_value,
#     289     )
#     290     if not handed_over:
#     291         raise Error.errorhandler_make_exception(
#     292             error_class,
#     293             error_value,
#     294         )
#
# File ~/anaconda3/lib/python3.11/site-packages/snowflake/connector/errors.py:342, in Error.hand_to_other_handler(connection, cursor, error_class, error_value)
#     340     return True
#     341 elif connection is not None:
# --> 342     connection.errorhandler(connection, cursor, error_class, error_value)
#     343     return True
#     344 return False
#
# File ~/anaconda3/lib/python3.11/site-packages/snowflake/connector/errors.py:215, in Error.default_errorhandler(connection, cursor, error_class, error_value)
#     213 errno = error_value.get("errno")
#     214 done_format_msg = error_value.get("done_format_msg")
# --> 215 raise error_class(
#     216     msg=error_value.get("msg"),
#     217     errno=None if errno is None else int(errno),
#     218     sqlstate=error_value.get("sqlstate"),
#     219     sfqid=error_value.get("sfqid"),
#     220     query=error_value.get("query"),
#     221     done_format_msg=(
#     222         None if done_format_msg is None else bool(done_format_msg)
#     223     ),
#     224     connection=connection,
#     225     cursor=cursor,
#     226 )
#
# InterfaceError: 250003 (08001): 404 Not Found: post https://your_account.snowflakecomputing.com:443/session/v1/login-request?request_id=cb79d36c-507f-4212-a5a1-ed20eb30bf50&databaseName=your_database&schemaName=your_schema&warehouse=your_warehouse&request_guid=f1a9f621-812e-42fd-9bca-c41d40e5d0cb
